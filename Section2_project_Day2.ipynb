# %% [markdown]
# <a href="https://colab.research.google.com/github/ysooch0819/AI16-Projects/blob/main/Section2_project_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import time
import json
from pandas import json_normalize

# %%
import re

# %%
# api_key = getAPIkey()
api_key = 'RGAPI-146f9057-11fb-4c6c-9d7f-52950a989078'

# %%
REGION_SET= 'kr'
tier = 'challenger'
request_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com"
}
url= 'https://kr.api.riotgames.com/tft/league/v1/challenger?api_key=' + api_key

req = requests.get(url)

# %%
len(req.json()['entries'])
# Out:
# 300

# %%
challenger_sample = pd.DataFrame(req.json()).reset_index()
challenger_sample.to_csv('sample.csv', index=False, encoding='cp949')

# %%
challenger_sample = pd.read_csv('sample.csv', encoding='cp949').set_index('index')
challenger_sample
# Out:
#              tier                              leagueId       queue  \
# index
# 0      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 1      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 2      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 3      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 4      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# ...           ...                                   ...         ...
# 295    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 296    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 297    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 298    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 299    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
#
#                     name                                            entries
# index
# 0      Orianna's Dragons  {'summonerId': 'Wq6S0VXK-5RxqhCIoj43jaY7yap4wl...
# 1      Orianna's Dragons  {'summonerId': 'kRsaMVAuKMJ98pVtiiHuIliwEpJiGq...
# 2      Orianna's Dragons  {'summonerId': 'LZYr5TN16DmatrYfG5nHRx7xjLLD-8...
# 3      Orianna's Dragons  {'summonerId': 'EevAodEB1ogihddloTtNQmr237TbPY...
# 4      Orianna's Dragons  {'summonerId': 'oarzOITC6LUddm097p5zMhpXFT2zeR...
# ...                  ...                                                ...
# 295    Orianna's Dragons  {'summonerId': 'alMRPqSjnkp4OII6-ZBbCdqdt3jXuh...
# 296    Orianna's Dragons  {'summonerId': 'UiV0CKlJ-tHX7LVwQ2Z95nxdox8OMn...
# 297    Orianna's Dragons  {'summonerId': 'cSXx2KKA1LyGEDbS1Od8GH_Zwoduvf...
# 298    Orianna's Dragons  {'summonerId': 'ZKKeGZw9l_c7hWyk_eJpVy0RCRjScN...
# 299    Orianna's Dragons  {'summonerId': 'la9MWpvJ81njFDXM-krIjkbc3OEF6y...
#
# [300 rows x 5 columns]

# %%
challenger_entries = pd.DataFrame(dict(challenger_sample['entries'])).T
challenger_entries
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d10e21d57f4e> in <module>
# ----> 1 challenger_entries = pd.DataFrame(dict(challenger_sample['entries'])).T
#       2 challenger_entries
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     623
#     624         if not indexes and not raw_lengths:
# --> 625             raise ValueError("If using all scalar values, you must pass an index")
#     626
#     627         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
challenger_sample = pd.concat([challenger_sample, challenger_entries], axis=1)

# %%
challenger_sample.head()
# Out:
#    index        tier                              leagueId       queue  \
# 0      0  CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 1      1  CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 2      2  CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 3      3  CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 4      4  CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
#
#                 name                                            entries  \
# 0  Orianna's Dragons  {'summonerId': 'Wq6S0VXK-5RxqhCIoj43jaY7yap4wl...
# 1  Orianna's Dragons  {'summonerId': 'kRsaMVAuKMJ98pVtiiHuIliwEpJiGq...
# 2  Orianna's Dragons  {'summonerId': 'LZYr5TN16DmatrYfG5nHRx7xjLLD-8...
# 3  Orianna's Dragons  {'summonerId': 'EevAodEB1ogihddloTtNQmr237TbPY...
# 4  Orianna's Dragons  {'summonerId': 'oarzOITC6LUddm097p5zMhpXFT2zeR...
#
#                                           summonerId summonerName  \
# 0     Wq6S0VXK-5RxqhCIoj43jaY7yap4wlOluyY2OKT35Gzvng          관자빵
# 1  kRsaMVAuKMJ98pVtiiHuIliwEpJiGqSDRVhfrS50TdPkwt...   Inv Artist
# 2    LZYr5TN16DmatrYfG5nHRx7xjLLD-8dmSTvgdb5Uk-88CcY       fanny1
# 3  EevAodEB1ogihddloTtNQmr237TbPYwIGPedgVJ4qum96X...          엠 돈
# 4    oarzOITC6LUddm097p5zMhpXFT2zeRSX4ZHJ77mv1zcfor0         철회랜드
#
#   leaguePoints rank wins losses veteran inactive freshBlood hotStreak
# 0         1026    I  202    170   False    False      False      True
# 1         1338    I  428    273    True    False      False      True
# 2         1088    I  377    340   False    False       True      True
# 3         1055    I  299    260   False    False      False     False
# 4         1025    I  196    158   False    False       True      True

# %%
challenger_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         300 non-null    int64
#  1   tier          300 non-null    object
#  2   leagueId      300 non-null    object
#  3   queue         300 non-null    object
#  4   name          300 non-null    object
#  5   entries       300 non-null    object
#  6   summonerId    300 non-null    object
#  7   summonerName  300 non-null    object
#  8   leaguePoints  300 non-null    object
#  9   rank          300 non-null    object
#  10  wins          300 non-null    object
#  11  losses        300 non-null    object
#  12  veteran       300 non-null    object
#  13  inactive      300 non-null    object
#  14  freshBlood    300 non-null    object
#  15  hotStreak     300 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 37.6+ KB

# %%
df = challenger_sample.copy()

# %%
df
# Out:
#              tier                              leagueId       queue  \
# index
# 0      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 1      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 2      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 3      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 4      CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# ...           ...                                   ...         ...
# 295    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 296    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 297    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 298    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
# 299    CHALLENGER  946274f2-16b6-376e-8d60-e07ef8f06a7f  RANKED_TFT
#
#                     name                                            entries
# index
# 0      Orianna's Dragons  {'summonerId': 'Wq6S0VXK-5RxqhCIoj43jaY7yap4wl...
# 1      Orianna's Dragons  {'summonerId': 'kRsaMVAuKMJ98pVtiiHuIliwEpJiGq...
# 2      Orianna's Dragons  {'summonerId': 'LZYr5TN16DmatrYfG5nHRx7xjLLD-8...
# 3      Orianna's Dragons  {'summonerId': 'EevAodEB1ogihddloTtNQmr237TbPY...
# 4      Orianna's Dragons  {'summonerId': 'oarzOITC6LUddm097p5zMhpXFT2zeR...
# ...                  ...                                                ...
# 295    Orianna's Dragons  {'summonerId': 'alMRPqSjnkp4OII6-ZBbCdqdt3jXuh...
# 296    Orianna's Dragons  {'summonerId': 'UiV0CKlJ-tHX7LVwQ2Z95nxdox8OMn...
# 297    Orianna's Dragons  {'summonerId': 'cSXx2KKA1LyGEDbS1Od8GH_Zwoduvf...
# 298    Orianna's Dragons  {'summonerId': 'ZKKeGZw9l_c7hWyk_eJpVy0RCRjScN...
# 299    Orianna's Dragons  {'summonerId': 'la9MWpvJ81njFDXM-krIjkbc3OEF6y...
#
# [300 rows x 5 columns]

# %%
# 필요없는 컬럼 제거: 'index', 'leagueId', 'queue', 'name', 'eentries', 'rank'
drop_cols = ['index', 'leagueId', 'queue', 'name', 'entries', 'rank']
df = df.drop(drop_cols, axis=1, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tier          300 non-null    object
#  1   entries       300 non-null    object
#  2   summonerId    300 non-null    object
#  3   summonerName  300 non-null    object
#  4   leaguePoints  300 non-null    object
#  5   wins          300 non-null    object
#  6   losses        300 non-null    object
#  7   veteran       300 non-null    object
#  8   inactive      300 non-null    object
#  9   freshBlood    300 non-null    object
#  10  hotStreak     300 non-null    object
# dtypes: object(11)
# memory usage: 25.9+ KB

# %%
df.to_csv('sample_user.csv', index=False, encoding='cp949')

# %%
## entries 딕셔너리에 들어있던 특성들 설명
# veteran : 현재 리그에서 최소 100게임 이상 플레이한 플레이어
# inactive : 휴면계정
# freshBlood : 최근에 리그에 합류한 새내기
# hotStreak : 연승 중인 플레이어

# %%
df.summonerName.nunique()
# Out:
# 300

# %%
match_id = pd.DataFrame()

for i in range(0, len(df)-1):
    url_puuid = 'https://kr.api.riotgames.com/tft/summoner/v1/summoners/by-name/'\
                +df.summonerName[i]+'?api_key=' + api_key
    url_match = 'https://asia.api.riotgames.com/tft/match/v1/matches/by-puuid/'\
                +requests.get(url_puuid).json()['puuid']+'/ids?start=0&count=200&api_key=' +api_key
    req_match = requests.get(url_match)
    match_id.append(req_match.json())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-354-23cd8ee0fe9d> in <module>
#       5                 +df.summonerName[i]+'?api_key=' + api_key
#       6     url_match = 'https://asia.api.riotgames.com/tft/match/v1/matches/by-puuid/'\
# ----> 7                 +requests.get(url_puuid).json()['puuid']+'/ids?start=0&count=200&api_key=' +api_key
#       8     req_match = requests.get(url_match)
#       9     match_id.append(req_match.json())
#
# KeyError: 'puuid'

# %%
match_id = pd.DataFrame()

# %%
for i in range(284, len(df)-1):
    url_puuid = 'https://kr.api.riotgames.com/tft/summoner/v1/summoners/by-name/'\
                  +df.summonerName[i]+'?api_key=' + api_key
    url_match = 'https://asia.api.riotgames.com/tft/match/v1/matches/by-puuid/'\
                  +requests.get(url_puuid).json()['puuid']+'/ids?start=0&count=200&api_key=' +api_key
    req_match = requests.get(url_match)
    match_id = match_id.append(req_match.json())

# %%
print('match_id 개수: ', len(match_id))
match_id
# Out:
# match_id 개수:  59598
#                  0
# 0    KR_6233363333
# 1    KR_6233290882
# 2    KR_6232501927
# 3    KR_6232409409
# 4    KR_6232324593
# ..             ...
# 195  KR_6082653943
# 196  KR_6082591610
# 197  KR_6082557590
# 198  KR_6082406064
# 199  KR_6081047025
#
# [59598 rows x 1 columns]

# %%
match_id = match_id.drop_duplicates()

# %%
len(match_id)
match_id.rename(columns = {0: 'match_id'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
match_id.to_csv('match_ID.csv', index=False, encoding='cp949')

# %%
match_id = pd.read_csv('match_ID.csv', encoding='cp949')
match_id
# Out:
#             match_id
# 0      KR_6233363333
# 1      KR_6233290882
# 2      KR_6232501927
# 3      KR_6232409409
# 4      KR_6232324593
# ...              ...
# 34773  KR_6082653943
# 34774  KR_6082591610
# 34775  KR_6082557590
# 34776  KR_6082406064
# 34777  KR_6081047025
#
# [34778 rows x 1 columns]

# %%
match_id # 34778 개의 중복되지 않은 챌린저티어 매치
# Out:
#             match_id
# 0      KR_6233363333
# 1      KR_6233290882
# 2      KR_6232501927
# 3      KR_6232409409
# 4      KR_6232324593
# ...              ...
# 34773  KR_6082653943
# 34774  KR_6082591610
# 34775  KR_6082557590
# 34776  KR_6082406064
# 34777  KR_6081047025
#
# [34778 rows x 1 columns]

# %%
df = match_id.copy()

# %%
df.iloc[0]['match_id']
# Out:
# 'KR_6233363333'

# %%
len(df)
# Out:
# 34778

# %%
import csv
f = open('rawdata.csv', encoding='cp949')
reader = csv.reader(f)
csv_list = []
for l in reader:
    csv_list.append(l)
f.close()
metadf = pd.DataFrame(csv_list)
metadf
# Out:
#                                                       0   \
# 0                                               augments
# 1      ['TFT6_Augment_JeweledLotus', 'TFT7_Augment_Pa...
# 2      ['TFT6_Augment_TradeSector', 'TFT6_Augment_Fir...
# 3      ['TFT6_Augment_TomeOfTraits1', 'TFT7_Augment_P...
# 4      ['TFT6_Augment_CelestialBlessing2', 'TFT6_Augm...
# ...                                                  ...
# 53484  ['TFT7_Augment_ClutteredMind', 'TFT6_Augment_T...
# 53485  ['TFT6_Augment_ThrillOfTheHunt2', 'TFT6_Augmen...
# 53486  ['TFT6_Augment_MetabolicAccelerator', 'TFT7_Au...
# 53487  ['TFT6_Augment_SecondWind2', 'TFT6_Augment_Pan...
# 53488  ['TFT7_Augment_WarriorEmblem', 'TFT6_Augment_F...
#
#                                                       1          2   \
# 0                                              companion  gold_left
# 1      {'content_ID': 'c4abff3d-3a21-48c4-940d-ad54b3...         50
# 2      {'content_ID': '6054d70b-e401-4bec-b350-f26865...          3
# 3      {'content_ID': '130a03b8-8dfe-47f8-9fa1-02d4ad...          1
# 4      {'content_ID': 'ee3fda5c-1956-44fe-a4a4-377483...          1
# ...                                                  ...        ...
# 53484  {'content_ID': 'c5a62aeb-1821-463b-a413-308814...          3
# 53485  {'content_ID': 'faaf16bc-0f78-4eb8-8262-d5fe54...          0
# 53486  {'content_ID': '1e3b0251-623c-41ee-87b0-ecba9a...         22
# 53487  {'content_ID': '8f032d75-83f7-445c-b2dd-751dc2...          3
# 53488  {'content_ID': 'fab64a15-f7d3-4313-9f7c-a88817...          1
#
#                3      4          5                   6   \
# 0      last_round  level  placement  players_eliminated
# 1              38      8          2                   2
# 2              27      8          7                   0
# 3              28      8          5                   0
# 4              31      8          3                   0
# ...           ...    ...        ...                 ...
# 53484          34      9          5                   0
# 53485          30      9          6                   0
# 53486          42      9          2                   2
# 53487          26      8          8                   0
# 53488          40      8          3                   0
#
#                                                       7                8   \
# 0                                                  puuid  time_eliminated
# 1      gihX7aaLSt3urJK1lTv3p87hA4aLaNhqwr030xceD9-pn1...       2311.57251
# 2      EDzYOAvlgpa2Mx5utJGl-7rMEysGqpEV1C82lO-QsiUXOd...       1690.70752
# 3      n6fDw9WjtVHOZqIxzP4WPoGlbBtxO13OE0ZJ-IoDoc4Oi4...      1762.875732
# 4      0Dy-7-nO1q539sOfPaFZuGyfmVI89QKyYyBcQqBg5UZSZh...      1878.452148
# ...                                                  ...              ...
# 53484  3jaPP00JihBvbfCwhymAg8JEedoe8_NH1sYeVCLNCqhRs1...      2080.717285
# 53485  QblvOFUsgqRM2MNYEUGQjrcGbQAMUWghkR5E1GXP4HTCaC...      1843.589722
# 53486  7uU38KHHvUjRsnbcupgzs2lCbIGGX49m8M9izajAhHV_1J...      2542.832275
# 53487  KSEzFINw43kPGV9oWlQ2iu3Q4qvm0n-DfH5o-oJQioxCOQ...      1585.390381
# 53488  eJ1ZcLopAz35zyBZxqV10Fvbjm7WMPjQes2q4pcRGngdch...      2443.347168
#
#                             9   \
# 0      total_damage_to_players
# 1                          183
# 2                           38
# 3                           69
# 4                          121
# ...                        ...
# 53484                       55
# 53485                       76
# 53486                      191
# 53487                       38
# 53488                      146
#
#                                                       10  \
# 0                                                 traits
# 1      [{'name': 'Set7_Assassin', 'num_units': 1, 'st...
# 2      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 3      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 4      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# ...                                                  ...
# 53484  [{'name': 'Set7_Astral', 'num_units': 3, 'styl...
# 53485  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 53486  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 53487  [{'name': 'Set7_Assassin', 'num_units': 1, 'st...
# 53488  [{'name': 'Set7_Bruiser', 'num_units': 1, 'sty...
#
#                                                       11                12
# 0                                                  units  partner_group_id
# 1      [{'character_id': 'TFT7_Vladimir', 'itemNames'...
# 2      [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 3      [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 4      [{'character_id': 'TFT7_Wukong', 'itemNames': ...
# ...                                                  ...               ...
# 53484  [{'character_id': 'TFT7_DragonGreen', 'itemNam...
# 53485  [{'character_id': 'TFT7_DragonGold', 'itemName...
# 53486  [{'character_id': 'TFT7_Jax', 'itemNames': ['T...
# 53487  [{'character_id': 'TFT7_Malphite', 'itemNames'...
# 53488  [{'character_id': 'TFT7_Leona', 'itemNames': [...
#
# [53489 rows x 13 columns]

# %%
metadf.rename(columns=metadf.iloc[0], inplace=True)
    # 0 : 'augments',
    # 1 : 'companion',
    # 2 : 'gold_left',
    # 3 : 'last_round',
    # 4 : 'level',
    # 5 : 'placement',
    # 6 : 'players_eliminated',
    # 7 : 'puuid',
    # 8 : 'time_eliminated',
    # 9 : 'total_damage_to_players',
    # 10 : 'traits',
    # 11 : 'units'
# }, inplace=True)

# %%
metadf = metadf.drop(0).reset_index(drop=True)

# %%
metadf
# Out:
#                                                 augments  \
# 0      ['TFT6_Augment_JeweledLotus', 'TFT7_Augment_Pa...
# 1      ['TFT6_Augment_TradeSector', 'TFT6_Augment_Fir...
# 2      ['TFT6_Augment_TomeOfTraits1', 'TFT7_Augment_P...
# 3      ['TFT6_Augment_CelestialBlessing2', 'TFT6_Augm...
# 4      ['TFT7_Augment_ShimmerscaleTrait', 'TFT7_Augme...
# ...                                                  ...
# 53483  ['TFT7_Augment_ClutteredMind', 'TFT6_Augment_T...
# 53484  ['TFT6_Augment_ThrillOfTheHunt2', 'TFT6_Augmen...
# 53485  ['TFT6_Augment_MetabolicAccelerator', 'TFT7_Au...
# 53486  ['TFT6_Augment_SecondWind2', 'TFT6_Augment_Pan...
# 53487  ['TFT7_Augment_WarriorEmblem', 'TFT6_Augment_F...
#
#                                                companion gold_left last_round  \
# 0      {'content_ID': 'c4abff3d-3a21-48c4-940d-ad54b3...        50         38
# 1      {'content_ID': '6054d70b-e401-4bec-b350-f26865...         3         27
# 2      {'content_ID': '130a03b8-8dfe-47f8-9fa1-02d4ad...         1         28
# 3      {'content_ID': 'ee3fda5c-1956-44fe-a4a4-377483...         1         31
# 4      {'content_ID': 'ee3fda5c-1956-44fe-a4a4-377483...         3         38
# ...                                                  ...       ...        ...
# 53483  {'content_ID': 'c5a62aeb-1821-463b-a413-308814...         3         34
# 53484  {'content_ID': 'faaf16bc-0f78-4eb8-8262-d5fe54...         0         30
# 53485  {'content_ID': '1e3b0251-623c-41ee-87b0-ecba9a...        22         42
# 53486  {'content_ID': '8f032d75-83f7-445c-b2dd-751dc2...         3         26
# 53487  {'content_ID': 'fab64a15-f7d3-4313-9f7c-a88817...         1         40
#
#       level placement players_eliminated  \
# 0         8         2                  2
# 1         8         7                  0
# 2         8         5                  0
# 3         8         3                  0
# 4         9         1                  2
# ...     ...       ...                ...
# 53483     9         5                  0
# 53484     9         6                  0
# 53485     9         2                  2
# 53486     8         8                  0
# 53487     8         3                  0
#
#                                                    puuid time_eliminated  \
# 0      gihX7aaLSt3urJK1lTv3p87hA4aLaNhqwr030xceD9-pn1...      2311.57251
# 1      EDzYOAvlgpa2Mx5utJGl-7rMEysGqpEV1C82lO-QsiUXOd...      1690.70752
# 2      n6fDw9WjtVHOZqIxzP4WPoGlbBtxO13OE0ZJ-IoDoc4Oi4...     1762.875732
# 3      0Dy-7-nO1q539sOfPaFZuGyfmVI89QKyYyBcQqBg5UZSZh...     1878.452148
# 4      Ad8Gb6OmmJ8u00gXFfLlN-fFCS_z95Ouj-filwtAlUd1BG...      2311.57251
# ...                                                  ...             ...
# 53483  3jaPP00JihBvbfCwhymAg8JEedoe8_NH1sYeVCLNCqhRs1...     2080.717285
# 53484  QblvOFUsgqRM2MNYEUGQjrcGbQAMUWghkR5E1GXP4HTCaC...     1843.589722
# 53485  7uU38KHHvUjRsnbcupgzs2lCbIGGX49m8M9izajAhHV_1J...     2542.832275
# 53486  KSEzFINw43kPGV9oWlQ2iu3Q4qvm0n-DfH5o-oJQioxCOQ...     1585.390381
# 53487  eJ1ZcLopAz35zyBZxqV10Fvbjm7WMPjQes2q4pcRGngdch...     2443.347168
#
#       total_damage_to_players  \
# 0                         183
# 1                          38
# 2                          69
# 3                         121
# 4                         207
# ...                       ...
# 53483                      55
# 53484                      76
# 53485                     191
# 53486                      38
# 53487                     146
#
#                                                   traits  \
# 0      [{'name': 'Set7_Assassin', 'num_units': 1, 'st...
# 1      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 2      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 3      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 4      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# ...                                                  ...
# 53483  [{'name': 'Set7_Astral', 'num_units': 3, 'styl...
# 53484  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 53485  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 53486  [{'name': 'Set7_Assassin', 'num_units': 1, 'st...
# 53487  [{'name': 'Set7_Bruiser', 'num_units': 1, 'sty...
#
#                                                    units partner_group_id
# 0      [{'character_id': 'TFT7_Vladimir', 'itemNames'...
# 1      [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 2      [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 3      [{'character_id': 'TFT7_Wukong', 'itemNames': ...
# 4      [{'character_id': 'TFT7_Nasus', 'itemNames': [...
# ...                                                  ...              ...
# 53483  [{'character_id': 'TFT7_DragonGreen', 'itemNam...
# 53484  [{'character_id': 'TFT7_DragonGold', 'itemName...
# 53485  [{'character_id': 'TFT7_Jax', 'itemNames': ['T...
# 53486  [{'character_id': 'TFT7_Malphite', 'itemNames'...
# 53487  [{'character_id': 'TFT7_Leona', 'itemNames': [...
#
# [53488 rows x 13 columns]

# %%
len(metadf)/8
# Out:
# 6686.0

# %%
testdf = metadf[3272:3280] # 삭제
testdf = metadf[6424:6432] # 삭제
testdf = metadf[6888:6896] # 삭제
testdf = metadf[11112:11120] # 삭제
testdf = metadf[13696:13704] # 삭제
testdf = metadf[30696:30704] # 삭제
testdf = metadf[36656:36664] # 삭제
testdf = metadf[36752:36760] # 삭제
testdf = metadf[44136:44144] # 삭제
testdf = metadf[44144:len(metadf)-8]
testdf = metadf[len(metadf)-8:len(metadf)]
testdf.placement.value_counts()
# Out:
# 1    1
# 7    1
# 4    1
# 5    1
# 6    1
# 2    1
# 8    1
# 3    1
# Name: placement, dtype: int64

# %%
newdf = metadf.drop(labels=range(3272, 3280), axis=0).drop(labels=range(6424, 6432), axis=0).drop(labels=range(6888, 6896), axis=0).drop(labels=range(11112,11120), axis=0).drop(labels=range(13696, 13704), axis=0).drop(labels=range(30696, 30704), axis=0).drop(labels=range(36656, 36664), axis=0).drop(labels=range(36752, 36760), axis=0).drop(labels=range(44136, 44144), axis=0)
newdf.placement.value_counts()
# Out:
# 2    6677
# 7    6677
# 5    6677
# 3    6677
# 1    6677
# 4    6677
# 6    6677
# 8    6677
# Name: placement, dtype: int64

# %%
newdf = newdf.drop_duplicates()

# %%
newdf = newdf.reset_index(drop=True)

# %%
# 6677개의 깨끗한 챌린저 게임 데이터 확보
newdf.to_csv('6677games.csv', index=False)

# %%
features = ['augments','companion','gold_left','last_round','level','placement','players_eliminated','puuid','time_eliminated','total_damage_to_players','traits','units']
metadf = metadf[features]

# %%
metadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68915 entries, 0 to 68914
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   augments                 68915 non-null  object
#  1   companion                68915 non-null  object
#  2   gold_left                68914 non-null  object
#  3   last_round               68909 non-null  object
#  4   level                    68907 non-null  object
#  5   placement                68907 non-null  object
#  6   players_eliminated       68907 non-null  object
#  7   puuid                    68907 non-null  object
#  8   time_eliminated          68907 non-null  object
#  9   total_damage_to_players  68907 non-null  object
#  10  traits                   68907 non-null  object
#  11  units                    68906 non-null  object
# dtypes: object(12)
# memory usage: 6.3+ MB

# %%
metadf = metadf.drop(0).reset_index(drop=True)

# %%
metadf = metadf.dropna().reset_index(drop=True)

# %%
metadf.head()
# Out:
#                                             augments  \
# 0  ['TFT6_Augment_JeweledLotus', 'TFT7_Augment_Pa...
# 1  ['TFT6_Augment_TradeSector', 'TFT6_Augment_Fir...
# 2  ['TFT6_Augment_TomeOfTraits1', 'TFT7_Augment_P...
# 3  ['TFT6_Augment_CelestialBlessing2', 'TFT6_Augm...
# 4  ['TFT7_Augment_ShimmerscaleTrait', 'TFT7_Augme...
#
#                                            companion gold_left last_round  \
# 0  {'content_ID': 'c4abff3d-3a21-48c4-940d-ad54b3...        50         38
# 1  {'content_ID': '6054d70b-e401-4bec-b350-f26865...         3         27
# 2  {'content_ID': '130a03b8-8dfe-47f8-9fa1-02d4ad...         1         28
# 3  {'content_ID': 'ee3fda5c-1956-44fe-a4a4-377483...         1         31
# 4  {'content_ID': 'ee3fda5c-1956-44fe-a4a4-377483...         3         38
#
#   level placement players_eliminated  \
# 0     8         2                  2
# 1     8         7                  0
# 2     8         5                  0
# 3     8         3                  0
# 4     9         1                  2
#
#                                                puuid time_eliminated  \
# 0  gihX7aaLSt3urJK1lTv3p87hA4aLaNhqwr030xceD9-pn1...      2311.57251
# 1  EDzYOAvlgpa2Mx5utJGl-7rMEysGqpEV1C82lO-QsiUXOd...      1690.70752
# 2  n6fDw9WjtVHOZqIxzP4WPoGlbBtxO13OE0ZJ-IoDoc4Oi4...     1762.875732
# 3  0Dy-7-nO1q539sOfPaFZuGyfmVI89QKyYyBcQqBg5UZSZh...     1878.452148
# 4  Ad8Gb6OmmJ8u00gXFfLlN-fFCS_z95Ouj-filwtAlUd1BG...      2311.57251
#
#   total_damage_to_players                                             traits  \
# 0                     183  [{'name': 'Set7_Assassin', 'num_units': 1, 'st...
# 1                      38  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 2                      69  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 3                     121  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 4                     207  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
#
#                                                units
# 0  [{'character_id': 'TFT7_Vladimir', 'itemNames'...
# 1  [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 2  [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 3  [{'character_id': 'TFT7_Wukong', 'itemNames': ...
# 4  [{'character_id': 'TFT7_Nasus', 'itemNames': [...

# %%
metadf = metadf.drop([28437, 31689, 16768, 61423]).reset_index(drop=True)

# %%
metadf.placement.value_counts()
# Out:
# 1    8697
# 5    8603
# 8    8603
# 4    8602
# 3    8600
# 2    8599
# 6    8599
# 7    8598
# Name: placement, dtype: int64

# %%
metadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68901 entries, 0 to 68900
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   augments                 68901 non-null  object
#  1   companion                68901 non-null  object
#  2   gold_left                68901 non-null  object
#  3   last_round               68901 non-null  object
#  4   level                    68901 non-null  object
#  5   placement                68901 non-null  int64
#  6   players_eliminated       68901 non-null  object
#  7   puuid                    68901 non-null  object
#  8   time_eliminated          68901 non-null  object
#  9   total_damage_to_players  68901 non-null  object
#  10  traits                   68901 non-null  object
#  11  units                    68901 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 6.3+ MB

# %%
df = metadf.drop(columns = ['companion', 'puuid'])
df
# Out:
#                                                 augments gold_left last_round  \
# 0      ['TFT6_Augment_JeweledLotus', 'TFT7_Augment_Pa...        50         38
# 1      ['TFT6_Augment_TradeSector', 'TFT6_Augment_Fir...         3         27
# 2      ['TFT6_Augment_TomeOfTraits1', 'TFT7_Augment_P...         1         28
# 3      ['TFT6_Augment_CelestialBlessing2', 'TFT6_Augm...         1         31
# 4      ['TFT7_Augment_ShimmerscaleTrait', 'TFT7_Augme...         3         38
# ...                                                  ...       ...        ...
# 68896  ['TFT6_Augment_TomeOfTraits1', 'TFT7_Augment_F...         1         33
# 68897  ['TFT6_Augment_TrueTwos', 'TFT7_Augment_Mikael...         1         31
# 68898  ['TFT6_Augment_Ascension', 'TFT6_Augment_Secon...         0         35
# 68899  ['TFT6_Augment_Ascension', 'TFT6_Augment_Porta...         7         41
# 68900  ['TFT7_Augment_AxiomArc2', 'TFT6_Augment_Elect...        11         26
#
#       level  placement players_eliminated time_eliminated  \
# 0         8          2                  2      2311.57251
# 1         8          7                  0      1690.70752
# 2         8          5                  0     1762.875732
# 3         8          3                  0     1878.452148
# 4         9          1                  2      2311.57251
# ...     ...        ...                ...             ...
# 68896     8          4                  1      1955.89209
# 68897     8          5                  0     1837.862305
# 68898     8          3                  0      2089.41333
# 68899     8          2                  2     2415.433105
# 68900     8          8                  0      1526.32251
#
#       total_damage_to_players  \
# 0                         183
# 1                          38
# 2                          69
# 3                         121
# 4                         207
# ...                       ...
# 68896                      79
# 68897                      96
# 68898                      89
# 68899                     169
# 68900                      30
#
#                                                   traits  \
# 0      [{'name': 'Set7_Assassin', 'num_units': 1, 'st...
# 1      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 2      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 3      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 4      [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# ...                                                  ...
# 68896  [{'name': 'Set7_Cavalier', 'num_units': 1, 'st...
# 68897  [{'name': 'Set7_Cavalier', 'num_units': 1, 'st...
# 68898  [{'name': 'Set7_Assassin', 'num_units': 2, 'st...
# 68899  [{'name': 'Set7_Bard', 'num_units': 1, 'style'...
# 68900  [{'name': 'Set7_Astral', 'num_units': 3, 'styl...
#
#                                                    units
# 0      [{'character_id': 'TFT7_Vladimir', 'itemNames'...
# 1      [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 2      [{'character_id': 'TFT7_Rakan', 'itemNames': [...
# 3      [{'character_id': 'TFT7_Wukong', 'itemNames': ...
# 4      [{'character_id': 'TFT7_Nasus', 'itemNames': [...
# ...                                                  ...
# 68896  [{'character_id': 'TFT7_Twitch', 'itemNames': ...
# 68897  [{'character_id': 'TFT7_Twitch', 'itemNames': ...
# 68898  [{'character_id': 'TFT7_Qiyana', 'itemNames': ...
# 68899  [{'character_id': 'TFT7_Zyra', 'itemNames': ['...
# 68900  [{'character_id': 'TFT7_Nasus', 'itemNames': [...
#
# [68901 rows x 10 columns]

# %%
winners = df['placement'] <= 4
len(df[winners]), len(df[~winners])
# Out:
# (34498, 34403)

# %%
raw_df = pd.DataFrame()

# %%
url_ingame = 'https://asia.api.riotgames.com/tft/match/v1/matches/'\
              +df.iloc[1]['match_id']+ '?api_key=' + api_key
metadf = metadf.append(pd.DataFrame(requests.get(url_ingame).json()['info']['participants']))

# %%
for i in range(3, 9706):
    time.sleep(0.4)
    url_ingame = 'https://asia.api.riotgames.com/tft/match/v1/matches/'+df.iloc[i]['match_id']+ '?api_key=' + api_key
    metadf = metadf.append(pd.DataFrame(requests.get(url_ingame).json()['info']['participants']))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-a65540a5bb01> in <module>
#       2     time.sleep(0.4)
#       3     url_ingame = 'https://asia.api.riotgames.com/tft/match/v1/matches/'+df.iloc[i]['match_id']+ '?api_key=' + api_key
# ----> 4     metadf = metadf.append(pd.DataFrame(requests.get(url_ingame).json()['info']['participants']))
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.8/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     595
#     596             # Make the request on the httplib connection object.
# --> 597             httplib_response = self._make_request(conn, method, url,
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /usr/local/lib/python3.8/dist-packages/urllib3/connection.py in connect(self)
#     335         context = self.ssl_context
#     336         context.verify_mode = resolve_cert_reqs(self.cert_reqs)
# --> 337         self.sock = ssl_wrap_socket(
#     338             sock=conn,
#     339             keyfile=self.key_file,
#
# /usr/local/lib/python3.8/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     343             or IS_SECURETRANSPORT):
#     344         if HAS_SNI and server_hostname is not None:
# --> 345             return context.wrap_socket(sock, server_hostname=server_hostname)
#     346
#     347         warnings.warn(
#
# /usr/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# /usr/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# /usr/lib/python3.8/ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
# %%time
url_ingame = 'https://asia.api.riotgames.com/tft/match/v1/matches/'+df.iloc[9707]['match_id']+ '?api_key=' + api_key
json_normalize(requests.get(url_ingame).json()['info']['participants'])
# raw_df = raw_df.append(json_normalize(requests.get(url_ingame).json()['info']['participants']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <timed exec> in <module>
#
# KeyError: 'info'

# %%
print(len(raw_df)/8)
raw_df.placement.value_counts()
# Out:
# 3.0
# 7    3
# 2    3
# 3    3
# 6    3
# 8    3
# 1    3
# 4    3
# 5    3
# Name: placement, dtype: int64

# %%
metadf.tail(8)
# Out:
#                                                 augments  \
# 12572  ['TFT6_Augment_PortableForge', 'TFT7_Augment_A...
# 12573  ['TFT7_Augment_GuildEmblem', 'TFT6_Augment_Ite...
# 12574  ['TFT6_Augment_JeweledLotus', 'TFT7_Augment_La...
# 12575  ['TFT7_Augment_ShimmerscaleTrait', 'TFT6_Augme...
# 12576  ['TFT7_Augment_AxiomArc2', 'TFT7_Augment_BandO...
# 12577  ['TFT7_Augment_ShimmerscaleTrait', 'TFT6_Augme...
# 12578  ['TFT7_Augment_SwiftshotEmblem', 'TFT6_Augment...
# 12579  ['TFT6_Augment_CyberneticUplink2', 'TFT6_Augme...
#
#                                                companion gold_left last_round  \
# 12572  {'content_ID': 'ee3fda5c-1956-44fe-a4a4-377483...         1         30
# 12573  {'content_ID': '5897ad9f-4665-4372-8f3e-6c878a...         2         35
# 12574  {'content_ID': '815a37f3-2cba-487c-bda9-6f49ef...        13         37
# 12575  {'content_ID': 'e83858ae-1837-401c-8330-f063cd...         8         26
# 12576  {'content_ID': 'c5a62aeb-1821-463b-a413-308814...         1         21
# 12577  {'content_ID': '54d41338-c532-4522-8bf4-521979...        24         30
# 12578  {'content_ID': '90c30ac2-94d9-4f5a-9c78-51f651...         0         41
# 12579  {'content_ID': 'b8d85a23-1946-4e31-acd5-97d7be...         1         41
#
#       level placement players_eliminated  \
# 12572     8         7                  0
# 12573     8         5                  2
# 12574     9         3                  1
# 12575     8         8                  0
# 12576     5         8                  0
# 12577     8         6                  0
# 12578     8         2                  2
# 12579     9         1                  1
#
#                                                    puuid time_eliminated  \
# 12572  1o5sWId6ZRm_eUMQqBy7f9vdvQAOeiAjvckZDZOJTpN5tM...      1806.55481
# 12573  3vJApffY1wzCp4o5ZyhhxHIu9Pc2fkSgltJMp1MMduHivr...     2120.306885
# 12574  9DEPnQysNaeEbh-Rbq6qRG7RJxVGHkZcxqBtV_LzkhInbj...      2232.18042
# 12575  VS6mODKhDud20CBCtPw1hRj9kgl70DOcjfVjr6we_FSgrJ...     1574.119385
# 12576  k-nYWDVyww6Vv9YKuMuxG_eC0qVqSTndcxQ5Pa6jr44jLX...     1299.802734
# 12577  OpEBGhInVTTK3hV9x0x2dH_GJbVeOdF9I7FPvZLuFqwczE...     1824.631714
# 12578  JfJyJYv79OCtj7nAnqEFke7WzJ_-Ar6PYz7G7fVfdA6gWs...     2443.937012
# 12579  4UlK42ZBlK-3GEmIGx3quFlgDt9Qdq7ugwboFHI0gv_yIV...     2443.937012
#
#       total_damage_to_players  ...    57    58    59    60    61    62    63  \
# 12572                     102  ...  None  None  None  None  None  None  None
# 12573                     130  ...  None  None  None  None  None  None  None
# 12574                     137  ...  None  None  None  None  None  None  None
# 12575                      37  ...  None  None  None  None  None  None  None
# 12576                       4  ...  None  None  None  None  None  None  None
# 12577                      57  ...  None  None  None  None  None  None  None
# 12578                     153  ...  None  None  None  None  None  None  None
# 12579                     236  ...  None  None  None  None  None  None  None
#
#          64    65    66
# 12572  None  None  None
# 12573  None  None  None
# 12574  None  None  None
# 12575  None  None  None
# 12576  None  None  None
# 12577  None  None  None
# 12578  None  None  None
# 12579  None  None  None
#
# [8 rows x 67 columns]

# %%
metadf.to_csv('rawdata.csv', index=False, encoding='cp949')

# %%
df.to_csv('test_df.csv', index=False)

# %%
# 'info' 안의 'participants' 특성에 해당 게임의 경기에서 8명의 전체유저들이 플레이한 기록이 들어있다.
# 관심있는것은 각 유저들의 해당 경기의 placement(최종순위)가 어떻게 되었는가이다.
# TFT의 랭크게임은 8명의 유저 중 최종 순위 1~4위까지는 tier 점수가 오르고, 5~8위는 tier 점수가 깎이는 방식으로 진행된다.
# 알고 싶은 것은 유저들이 게임 내 어떠한 선택지를 골랐을 때 tier(점수)를 쉽게 올릴 수 있을까? 것이므로, 게임별 상위 4명의 데이터와 하위 4명의 데이터를 별도로 분석한다.
# 필요하다면 Grandmaster, master 의 데이터도 소량 가져와야한다.

# %%
# 안정적인 티어덱은 무엇인가?
# target = 'placement'
# 순위와 직접적으로 연결되는 특성은 배제
# 'last_round' : 유저가 생존한 최종 round 수, 1등과 2등/3등이 마지막 round를 진행할테니 상위로 갈수록 높을 수 밖에 없다.
# 'time_eliminated': 유저가 플레이한 전체 시간, 위와 동일한 이유
# 
# 'augments', 'gold_left', 'level', 'total_damage_to_players', 'traits', 'units' 를 활용해 분석해야한다.
